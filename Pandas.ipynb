# %%
import numpy as np
import pandas as pd

# %%
movie=pd.read_csv('bollywood.csv')

# %%
movie
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
movie.shape
# Out:
# (1284, 10)

# %%
movie.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movie.tail()
# Out:
#          imdbId                 title  releaseYear  releaseDate     genre  \
# 1279  tt4121522  Shuruaat Ka Interval         2014  15 Aug 2014       NaN
# 1280  tt4187650      Trip to Bhangarh         2014  28 Aug 2014    Horror
# 1281  tt4190220              Zed Plus         2014  28 Nov 2014       NaN
# 1282  tt4219300       Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746                   Zid         2014  28 Nov 2014  Thriller
#
#                                                 writers  \
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                                NaN
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                                NaN
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# ...

# %%
movie.tail(2)
# Out:
#          imdbId            title  releaseYear  releaseDate     genre  \
# 1282  tt4219300  Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746              Zid         2014  28 Nov 2014  Thriller
#
#                                writers  \
# 1282                               NaN
# 1283  Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1282  Vir Das | Sandeepa Dhar | Rahul Handa | Dimple...
# 1283  Shradha Das | Mohan Kapoor | Mannara | Karanvi...
#
#                            directors  sequel  hitFlop
# 1282                  Kabir Sadanand     0.0        1
# 1283  Rohit Malhotra | Anubhav Sinha     0.0        2

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null float64
# hitFlop        1284 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
movie.describe()
# Out:
#        releaseYear       sequel      hitFlop
# count  1284.000000  1281.000000  1284.000000
# mean   2007.989097     0.035129     2.144081
# std       4.005243     0.188371     1.812820
# min    2001.000000     0.000000     1.000000
# 25%    2004.000000     0.000000     1.000000
# 50%    2008.000000     0.000000     1.000000
# 75%    2011.000000     0.000000     2.000000
# max    2014.000000     2.000000     9.000000

# %%
movie.corr()
# Out:
#              releaseYear    sequel   hitFlop
# releaseYear     1.000000  0.132172  0.009878
# sequel          0.132172  1.000000  0.251237
# hitFlop         0.009878  0.251237  1.000000

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
movie['title']
# Out:
# 0                                  Albela
# 1       Lagaan: Once Upon a Time in India
# 2                Meri Biwi Ka Jawab Nahin
# 3                  Hum Tumhare Hain Sanam
# 4                              One 2 Ka 4
#                       ...
# 1279                 Shuruaat Ka Interval
# 1280                     Trip to Bhangarh
# 1281                             Zed Plus
# 1282                      Gollu aur Pappu
# 1283                                  Zid
# Name: title, Length: 1284, dtype: object

# %%
movie['hitFlop']
# Out:
# 0       2
# 1       6
# 2       1
# 3       4
# 4       1
#        ..
# 1279    1
# 1280    1
# 1281    1
# 1282    1
# 1283    2
# Name: hitFlop, Length: 1284, dtype: int64

# %%
type(movie['title'])
# Out:
# pandas.core.series.Series

# %%
movie['title'].index
# Out:
# RangeIndex(start=0, stop=1284, step=1)

# %%
type(movie['title'].values)
# Out:
# numpy.ndarray

# %%
movie['title'].values
# Out:
# array(['Albela', 'Lagaan: Once Upon a Time in India',
#        'Meri Biwi Ka Jawab Nahin', ..., 'Zed Plus', 'Gollu aur Pappu',
#        'Zid'], dtype=object)

# %%
movie[['title','hitFlop']]
# Out:
#                                   title  hitFlop
# 0                                Albela        2
# 1     Lagaan: Once Upon a Time in India        6
# 2              Meri Biwi Ka Jawab Nahin        1
# 3                Hum Tumhare Hain Sanam        4
# 4                            One 2 Ka 4        1
# ...                                 ...      ...
# 1279               Shuruaat Ka Interval        1
# 1280                   Trip to Bhangarh        1
# 1281                           Zed Plus        1
# 1282                    Gollu aur Pappu        1
# 1283                                Zid        2
#
# [1284 rows x 2 columns]

# %%
movie['genre']=='Romance'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# 1259    False
# 1260    False
# 1261    False
# 1262    False
# 1263    False
# 1264    False
# 1265    False
# 1266    False
# 1267    False
# 1268    False
# 1269    False
# 1270    False
# 1271    False
# 1272    False
# 1273    False
# 1274    False
# 1275    False
# 1276    False
# 1277    False
# 1278    False
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# ...

# %%
movie[movie['genre']=='Horror'].shape
# Out:
# (13, 10)

# %%
movie[movie['hitFlop']>8]
# Out:
#          imdbId                 title  releaseYear  releaseDate  \
# 32    tt0284137  Gadar: Ek Prem Katha         2001  15 Jun 2001
# 625   tt1187043              3 Idiots         2009  25 Dec 2009
# 901   tt1833673              Dhoom: 3         2013  20 Dec 2013
# 1092  tt2338151                    PK         2014  19 Dec 2014
#
#                           genre  \
# 32     Action | Drama | Romance
# 625              Comedy | Drama
# 901   Action | Crime | Thriller
# 1092   Comedy | Drama | Fantasy
#
#                                                 writers  \
# 32                                    Shaktimaan Talwar
# 625   Rajkumar Hirani | Abhijit Joshi | Vidhu Vinod ...
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 1092  Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
#
#                                                  actors  \
# 32    Sunny Deol | Ameesha Patel | Amrish Puri | Lil...
# 625   Aamir Khan | Kareena Kapoor | Madhavan | Sharm...
# ...

# %%
movie[movie['releaseYear']>2010].shape
# Out:
# (423, 10)

# %%
mask1=movie['releaseYear']>2010
mask2=movie['hitFlop']>8
movie[mask1 & mask2]
#movie[movie['releaseYear']>2010 & movie['hitFlop']>8]    ----> will nor work
# Out:
#          imdbId     title  releaseYear  releaseDate  \
# 901   tt1833673  Dhoom: 3         2013  20 Dec 2013
# 1092  tt2338151        PK         2014  19 Dec 2014
#
#                           genre  \
# 901   Action | Crime | Thriller
# 1092   Comedy | Drama | Fantasy
#
#                                                 writers  \
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 1092  Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
#
#                                                  actors  \
# 901   Aamir Khan | Katrina Kaif | Tabrett Bethell | ...
# 1092  Aamir Khan | Anushka Sharma | Sanjay Dutt | Bo...
#
#                   directors  sequel  hitFlop
# 901   Vijay Krishna Acharya     1.0        9
# 1092        Rajkumar Hirani     0.0        9

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null float64
# hitFlop        1284 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
movie['sequel']=movie['sequel'].astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null category
# hitFlop        1284 non-null int64
# dtypes: category(1), int64(2), object(7)
# memory usage: 91.7+ KB

# %%
movie
# Out:
#          imdbId                                title  releaseYear  \
# 0     tt0118578                               Albela         2001
# 1     tt0169102    Lagaan: Once Upon a Time in India         2001
# 2     tt0187279             Meri Biwi Ka Jawab Nahin         2004
# 3     tt0222024               Hum Tumhare Hain Sanam         2002
# 4     tt0227194                           One 2 Ka 4         2001
# 5     tt0238936                               Devdas         2002
# 6     tt0247911          Aap Mujhe Achche Lagne Lage         2002
# 7     tt0248126          Kabhi Khushi Kabhie Gham...         2001
# 8     tt0248216                  Na Tum Jaano Na Hum         2002
# 9     tt0248617                           Yaadein...         2001
# 10    tt0255713                             Zubeidaa         2001
# 11    tt0256692            Chori Chori Chupke Chupke         2001
# 12    tt0265148             Main Prem Ki Diwani Hoon         2003
# ...

# %%
movie.iloc[0,:]
# Out:
# imdbId                                                 tt0118578
# title                                                     Albela
# releaseYear                                                 2001
# releaseDate                                          20 Apr 2001
# genre                                                    Romance
# writers        Honey Irani (screenplay) | Honey Irani (story)...
# actors         Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# directors                                          Deepak Sareen
# sequel                                                         0
# hitFlop                                                        2
# Name: 0, dtype: object

# %%
movie.iloc[::2,[1,7,8,9]]
# Out:
#                                     title  \
# 0                                  Albela
# 2                Meri Biwi Ka Jawab Nahin
# 4                              One 2 Ka 4
# 6             Aap Mujhe Achche Lagne Lage
# 8                     Na Tum Jaano Na Hum
# 10                               Zubeidaa
# 12               Main Prem Ki Diwani Hoon
# 14                            Chandni Bar
# 16                                 Censor
# 18             Mujhe Meri Biwi Se Bachaao
# 20    Daman: A Victim of Marital Violence
# 22                  Dil Ne Phir Yaad Kiya
# 24                                 Grahan
# 26                                Ajnabee
# 28      Chhupa Rustam: A Musical Thriller
# 30                 Pyaar Tune Kya Kiya...
# 32                   Gadar: Ek Prem Katha
# 34                              Paagalpan
# 36                                 Uljhan
# 38       Tum Bin...: Love Will Find a Way
# 40                         Dil Chahta Hai
# ...

# %%
movie.sort_values('title')
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 406   tt0473567                           ...Yahaan         2005  29 Jul 2005
# 732   tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 74    tt0313844                         16 December         2002  22 Mar 2002
# 700   tt1301698                                1920         2008  12 Sep 2008
# 1048  tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 1061  tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 391   tt0463279                           2 October         2003          NaN
# 1114  tt2372678                            2 States         2014  18 Apr 2014
# 89    tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 642   tt1216276                26th July at Barista         2008  14 Mar 2008
# 1266  tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
movie.sort_values('title',inplace=True)

# %%
movie
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 406   tt0473567                           ...Yahaan         2005  29 Jul 2005
# 732   tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 74    tt0313844                         16 December         2002  22 Mar 2002
# 700   tt1301698                                1920         2008  12 Sep 2008
# 1048  tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 1061  tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 391   tt0463279                           2 October         2003          NaN
# 1114  tt2372678                            2 States         2014  18 Apr 2014
# 89    tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 642   tt1216276                26th July at Barista         2008  14 Mar 2008
# 1266  tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
movie.sort_values('title',ascending=False)
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 10    tt0255713                            Zubeidaa         2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# 806   tt1605790                            Zokkomon         2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam         2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara         2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai         2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50         2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks         2006  06 Oct 2006
# 445   tt0488906                               Zinda         2006  12 Jan 2006
# 1283  tt4228746                                 Zid         2014  28 Nov 2014
# 364   tt0451983                               Zeher         2005  25 Mar 2005
# ...

# %%
movie.sort_values(['releaseYear','title'])
# Out:
#          imdbId                                title  releaseYear  \
# 58    tt0305173     Aamdani Atthanni Kharcha Rupaiya         2001
# 21    tt0273406                               Aashiq         2001
# 26    tt0278291                              Ajnabee         2001
# 37    tt0289845                                  Aks         2001
# 0     tt0118578                               Albela         2001
# 526   tt0926187                          Arjun Devaa         2001
# 139   tt0346548                                Avgat         2001
# 31    tt0283911            Bas Itna Sa Khwaab Hai...         2001
# 420   tt0477574                         Bengal Tiger         2001
# 393   tt0466208                              Bhairav         2001
# 678   tt1259755                                Boond         2001
# 16    tt0272543                               Censor         2001
# 14    tt0267363                          Chandni Bar         2001
# ...

# %%
movie.sort_values(['releaseYear','title'],ascending=[False,False])
# Out:
#          imdbId                                title  releaseYear  \
# 1283  tt4228746                                  Zid         2014
# 1281  tt4190220                             Zed Plus         2014
# 1243  tt3514330                          Youngistaan         2014
# 1244  tt3524410                     Yeh Hai Bakrapur         2014
# 1229  tt3382148                             Yaariyan         2014
# 1218  tt3303416                               Ya Rab         2014
# 1226  tt3362728                                Ungli         2014
# 1029  tt2187167                        Unforgettable         2014
# 1280  tt4187650                     Trip to Bhangarh         2014
# 1164  tt2727028                          Total Chaos         2014
# 1220  tt3309844                            Titoo MBA         2014
# 1259  tt3645014                            The Xpose         2014
# 1272  tt3848888                        The Shaukeens         2014
# ...

# %%
movie['imdbId'].is_unique
# Out:
# True

# %%
movie.set_index('imdbId',inplace=True)

# %%
movie
# Out:
#                                         title  releaseYear  releaseDate  \
# imdbId
# tt0473567                           ...Yahaan         2005  29 Jul 2005
# tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# tt0313844                         16 December         2002  22 Mar 2002
# tt1301698                                1920         2008  12 Sep 2008
# tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# tt0463279                           2 October         2003          NaN
# tt2372678                            2 States         2014  18 Apr 2014
# tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# tt1216276                26th July at Barista         2008  14 Mar 2008
# tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# tt2224254                         3 Bachelors         2012  29 Jun 2012
# ...

# %%
movie.reset_index(inplace=True)

# %%
movie
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 0     tt0473567                           ...Yahaan         2005  29 Jul 2005
# 1     tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 2     tt0313844                         16 December         2002  22 Mar 2002
# 3     tt1301698                                1920         2008  12 Sep 2008
# 4     tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 5     tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 6     tt0463279                           2 October         2003          NaN
# 7     tt2372678                            2 States         2014  18 Apr 2014
# 8     tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 9     tt1216276                26th July at Barista         2008  14 Mar 2008
# 10    tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
movie['title'].reset_index()
# Out:
#       index                               title
# 0         0                           ...Yahaan
# 1         1         13B: Fear Has a New Address
# 2         2                         16 December
# 3         3                                1920
# 4         4                  1920: Evil Returns
# 5         5             2 Nights in Soul Valley
# 6         6                           2 October
# 7         7                            2 States
# 8         8            23rd March 1931: Shaheed
# 9         9                26th July at Barista
# 10       10       3 AM: A Paranormal Experience
# 11       11                         3 Bachelors
# 12       12                            3 Idiots
# 13       13                     3 Nights 4 Days
# 14       14                             30 Days
# 15       15                       36 China Town
# 16       16            3G - A Killer Connection
# 17       17                404: Error Not Found
# 18       18        5ters: Castle of Dark Master
# ...

# %%
def hitYaFlop(number):
    if number>6:
        return "Hit"
    else:
        return "Flop"

# %%
hitYaFlop(8)
# Out:
# 'Hit'

# %%
movie['verdict']=movie['hitFlop'].apply(hitYaFlop)

# %% [markdown]
# movie

# %%
movie
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 0     tt0473567                           ...Yahaan         2005  29 Jul 2005
# 1     tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 2     tt0313844                         16 December         2002  22 Mar 2002
# 3     tt1301698                                1920         2008  12 Sep 2008
# 4     tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 5     tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 6     tt0463279                           2 October         2003          NaN
# 7     tt2372678                            2 States         2014  18 Apr 2014
# 8     tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 9     tt1216276                26th July at Barista         2008  14 Mar 2008
# 10    tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
movie.head(2)
# Out:
#       imdbId                        title  releaseYear  releaseDate  \
# 0  tt0473567                    ...Yahaan         2005  29 Jul 2005
# 1  tt1385824  13B: Fear Has a New Address         2009  06 Mar 2009
#
#                       genre  \
# 0                   Romance
# 1  Drama | Horror | Mystery
#
#                                              writers  \
# 0  Sameer Kohli | Mahesh (screenplay) | Mahesh (s...
# 1       Abhinav Kashyap (dialogue) | Vikram K. Kumar
#
#                                               actors        directors sequel  \
# 0  Jimmy Shergill | Minissha Lamba | Yashpal Shar...   Shoojit Sircar    0.0
# 1  Madhavan | Neetu Chandra | Poonam Dhillon | Sa...  Vikram K. Kumar    0.0
#
#    hitFlop verdict
# 0        1    Flop
# 1        2    Flop

# %%
movie['sequel'].value_counts()
# Out:
# 0.0    1237
# 1.0      43
# 2.0       1
# Name: sequel, dtype: int64

# %%
movie['releaseYear'].value_counts()
# Out:
# 2010    116
# 2011    112
# 2014    110
# 2005    106
# 2013    102
# 2012     99
# 2008     98
# 2003     95
# 2009     91
# 2004     88
# 2002     79
# 2007     66
# 2001     62
# 2006     60
# Name: releaseYear, dtype: int64

# %%
movie
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 0     tt0473567                           ...Yahaan         2005  29 Jul 2005
# 1     tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 2     tt0313844                         16 December         2002  22 Mar 2002
# 3     tt1301698                                1920         2008  12 Sep 2008
# 4     tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 5     tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 6     tt0463279                           2 October         2003          NaN
# 7     tt2372678                            2 States         2014  18 Apr 2014
# 8     tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 9     tt1216276                26th July at Barista         2008  14 Mar 2008
# 10    tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
movie.dropna().shape
# Out:
# (1131, 11)

# %%
movie.dropna(how='all').shape
# Out:
# (1284, 11)

# %%
movie.dropna(subset=['writers']).shape
# Out:
# (1165, 11)

# %%
movie.dropna(subset=['writers','sequel']).shape
# Out:
# (1163, 11)

# %%
movie.fillna({'writers':'no writers'},inplace=True)

# %%
movie['writers'].count()
# Out:
# 1284

# %%
movie.drop('imdbId',axis=1)
# Out:
#                                    title  releaseYear  releaseDate  \
# 0                              ...Yahaan         2005  29 Jul 2005
# 1            13B: Fear Has a New Address         2009  06 Mar 2009
# 2                            16 December         2002  22 Mar 2002
# 3                                   1920         2008  12 Sep 2008
# 4                     1920: Evil Returns         2012  02 Nov 2012
# 5                2 Nights in Soul Valley         2012  28 Dec 2012
# 6                              2 October         2003          NaN
# 7                               2 States         2014  18 Apr 2014
# 8               23rd March 1931: Shaheed         2002  07 Jun 2002
# 9                   26th July at Barista         2008  14 Mar 2008
# 10         3 AM: A Paranormal Experience         2014  26 Sep 2014
# 11                           3 Bachelors         2012  29 Jun 2012
# 12                              3 Idiots         2009  25 Dec 2009
# ...

# %%
movie.drop(columns=['imdbId','title'])
# Out:
#       releaseYear  releaseDate                          genre  \
# 0            2005  29 Jul 2005                        Romance
# 1            2009  06 Mar 2009       Drama | Horror | Mystery
# 2            2002  22 Mar 2002       Action | Drama | Mystery
# 3            2008  12 Sep 2008       Drama | Horror | Mystery
# 4            2012  02 Nov 2012       Drama | Horror | Romance
# 5            2012  28 Dec 2012   Adventure | Horror | Mystery
# 6            2003          NaN                          Crime
# 7            2014  18 Apr 2014                Drama | Romance
# 8            2002  07 Jun 2002    Biography | Drama | History
# 9            2008  14 Mar 2008                          Drama
# 10           2014  26 Sep 2014               Horror | Romance
# 11           2012  29 Jun 2012               Comedy | Romance
# 12           2009  25 Dec 2009                 Comedy | Drama
# 13           2009  09 Oct 2009                        Romance
# ...

# %%
movie.drop(0)
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 1     tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 2     tt0313844                         16 December         2002  22 Mar 2002
# 3     tt1301698                                1920         2008  12 Sep 2008
# 4     tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 5     tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 6     tt0463279                           2 October         2003          NaN
# 7     tt2372678                            2 States         2014  18 Apr 2014
# 8     tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 9     tt1216276                26th July at Barista         2008  14 Mar 2008
# 10    tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# 11    tt2224254                         3 Bachelors         2012  29 Jun 2012
# ...

# %%
movie.drop_duplicates().shape
# Out:
# (1284, 11)

# %% [markdown]
# movie.drop_duplicates(subset=['releaseYear'])

# %%
movie.drop_duplicates(subset=['releaseYear'],keep='last')
# Out:
#          imdbId                    title  releaseYear  releaseDate  \
# 1231  tt1610452         Wedding Planners         2010  10 Dec 2010
# 1232  tt0488798                  Welcome         2007  21 Dec 2007
# 1267  tt0382383                     Yuva         2004  22 May 2004
# 1268  tt1105747                 Yuvvraaj         2008  21 Nov 2008
# 1270  tt0382385                   Zameen         2003  26 Sep 2003
# 1273  tt0451983                    Zeher         2005  25 Mar 2005
# 1274  tt4228746                      Zid         2014  28 Nov 2014
# 1276  tt0823261           Zindaggi Rocks         2006  06 Oct 2006
# 1277  tt2929840            Zindagi 50 50         2013  24 May 2013
# 1278  tt0340464  Zindagi Khoobsoorat Hai         2002  04 Oct 2002
# 1280  tt2164702        Zindagi Tere Naam         2012  16 Mar 2012
# 1281  tt1605790                 Zokkomon         2011  22 Apr 2011
# 1282  tt1479857   Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# ...

# %%
movie.drop_duplicates(subset=['releaseYear','directors']).shape
# Out:
# (1230, 11)

# %%
movie.rename(columns={'title':'name','releaseYear':'year'})
# Out:
#          imdbId                                name  year  releaseDate  \
# 0     tt0473567                           ...Yahaan  2005  29 Jul 2005
# 1     tt1385824         13B: Fear Has a New Address  2009  06 Mar 2009
# 2     tt0313844                         16 December  2002  22 Mar 2002
# 3     tt1301698                                1920  2008  12 Sep 2008
# 4     tt2222550                  1920: Evil Returns  2012  02 Nov 2012
# 5     tt2246533             2 Nights in Soul Valley  2012  28 Dec 2012
# 6     tt0463279                           2 October  2003          NaN
# 7     tt2372678                            2 States  2014  18 Apr 2014
# 8     tt0324951            23rd March 1931: Shaheed  2002  07 Jun 2002
# 9     tt1216276                26th July at Barista  2008  14 Mar 2008
# 10    tt3720634       3 AM: A Paranormal Experience  2014  26 Sep 2014
# 11    tt2224254                         3 Bachelors  2012  29 Jun 2012
# ...

# %%
food=pd.read_csv('food.csv')

# %%
food.head()
# Out:
#      Name Gender     City Frequency      Item  Spends
# 0  Nitish      M  Kolkata    Weekly    Burger      11
# 1     Anu      F  Gurgaon     Daily  Sandwich      14
# 2   Mukku      M  Kolkata      Once      Vada      25
# 3    Suri      M  Kolkata   Monthly     Pizza      56
# 4   Rajiv      M    Patna     Never    Paneer      34

# %%
food.pivot_table(index=['Item','Gender'],columns=['City','Frequency'],values='Spends',aggfunc='mean')
# Out:
# City            Chennai                      Gurgaon                      \
# Frequency         Daily Monthly  Once Weekly   Daily Monthly Never  Once
# Item     Gender
# Burger   F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN  44.0    NaN     NaN     NaN   NaN   NaN
# Chicken  F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
# Paneer   F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN    67.0   NaN    NaN     NaN     NaN   NaN   NaN
# Pizza    F         34.0     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN  54.0    NaN     NaN     NaN   NaN   NaN
# Sandwich F          NaN     NaN   NaN   43.0    14.0     NaN   NaN   NaN
#          M          NaN    43.0   NaN    NaN     NaN     NaN  34.0  98.0
# Vada     F          NaN     NaN  23.0    NaN     NaN    86.0   NaN   NaN
# ...

# %%
company=pd.read_csv('Fortune501.csv')

# %%
company.head()
# Out:
#    Rank               Title  Employees       Sector  \
# 0     1             Walmart    2300000    Retailing
# 1     2  Berkshire Hathaway     367700   Financials
# 2     3               Apple     116000   Technology
# 3     4         Exxon Mobil      72700       Energy
# 4     5            McKesson      68000  Wholesalers
#
#                                    Industry         Hqlocation  Revenues  \
# 0                     General Merchandisers    Bentonville, AR    485873
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE    223604
# 2               Computers, Office Equipment      Cupertino, CA    215639
# 3                        Petroleum Refining         Irving, TX    205004
# 4                  Wholesalers: Health Care  San Francisco, CA    192487
#
#    Profits
# 0  13643.0
# 1  24074.0
# 2  45687.0
# 3   7840.0
# 4   2258.0

# %%
sectors=company.groupby('Sector')

# %%
sectors

# %%
sectors.size().sort_values(ascending=False).index[0]
# Out:
# 'Financials'

# %%
sectors.sum()['Revenues'].sort_values(ascending=False)
# Out:
# Sector
# Financials                       2067607
# Retailing                        1383281
# Health Care                      1318389
# Technology                       1257589
# Energy                           1176417
# Wholesalers                       799416
# Food, Beverages & Tobacco         472806
# Telecommunications                459978
# Industrials                       418359
# Motor Vehicles & Parts            392466
# Food & Drug Stores                389686
# Transportation                    354733
# Aerospace & Defense               338302
# Business Services                 194685
# Chemicals                         188667
# Household Products                180846
# Media                             180767
# Materials                         169755
# Engineering & Construction        124682
# Hotels, Restaurants & Leisure     121189
# Apparel                            66254
# Name: Revenues, dtype: int64

# %%
sectors.mean()['Profits'].sort_values(ascending=False)
# Out:
# Sector
# Technology                       4137.241860
# Telecommunications               4127.280000
# Health Care                      2773.260526
# Financials                       2719.776190
# Food, Beverages & Tobacco        2346.183333
# Aerospace & Defense              2093.308333
# Motor Vehicles & Parts           1919.533333
# Media                            1821.336364
# Industrials                      1727.689474
# Transportation                   1670.294118
# Household Products               1650.308333
# Hotels, Restaurants & Leisure    1451.060000
# Apparel                          1263.700000
# Food & Drug Stores               1217.428571
# Business Services                1155.355000
# Chemicals                        1137.021429
# Retailing                         991.785106
# Wholesalers                       391.279310
# Engineering & Construction        390.169231
# Materials                         272.468421
# Energy                              6.501754
# ...

# %%
sectors.get_group('Technology')
# Out:
#      Employees          Hqlocation  \
# 2       116000       Cupertino, CA
# 11      341400         Seattle, WA
# 26       72053   Mountain View, CA
# 27      114000         Redmond, WA
# 31      414400          Armonk, NY
# 40      138000      Round Rock, TX
# 46      106000     Santa Clara, CA
# 58      195000       Palo Alto, CA
# 59       73700        San Jose, CA
# 60       49000       Palo Alto, CA
# 80      136000    Redwood City, CA
# 97       17048      Menlo Park, CA
# 118      30500       San Diego, CA
# 143      62000      Washington, DC
# 151     138000  St. Petersburg, FL
# 153      54800         Waltham, MA
# 161     133600         Norwalk, CT
# 198       8516    Lincolnshire, IL
# 204     260200         Teaneck, NJ
# 205      29865          Dallas, TX
# 216      72878          Irvine, CA
# 225      31400           Boise, ID
# 264      16150     Santa Clara, CA
# 267      18500         Norwalk, CT
# 309      12600        San Jose, CA
# ...
